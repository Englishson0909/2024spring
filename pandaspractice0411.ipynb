# %% [markdown]
# <a href="https://colab.research.google.com/github/Englishson0909/2024spring/blob/main/pandaspractice0411.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv ("/content/HFwords.csv")

# %%
df.to_csv("/content/sample.csv")

# %%
url="https://raw.githubusercontent.com/Englishson0909/2024spring/main/HFwords.csv"
df1=pd.read_csv (url)
df1.head()
# Out:
#   Word  Frequency
# 0  the       1951
# 1   be       3455
# 2   to       4798
# 3   of       3822
# 4  and       3969

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
