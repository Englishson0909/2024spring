# %% [markdown]
# <a href="https://colab.research.google.com/github/Englishson0909/2024spring/blob/main/0413.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wordcloud matplotlib

# %%
text ="""I think the history of Denmark has much to teach us all.
The book has been published in many countries now, translated into countless different languages from Hungarian to Hebrew. Everywhere children are still reading about the integrity that a small Scandinavian population showed almost seventy years ago. Books do change lives, I know; and many readers have told me that Number the Stars changed theirs when they were young, that it made them think about both cruelty and courage. A young woman recently told that It was something that shaped my idea of how people should be treated, recalling her own fourth grade experience with the book.
The Danish friend who originally told me the story of her childhood in Copenhagen in 1943, and who became the prototype for the fictional Annemarie, is an old woman now. So am I. We both love thinking of the children reading the story today, coming to it for the first time and
realizing that once, for a brief time and in a small place, a group of prejudice-free people honored the humanity of others."""

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate word cloud
wordcloud = WordCloud(width = 800, height = 800,
                      background_color ='white',
                      min_font_size = 10).generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
text="""I think the history of Denmark has much to teach us all.
The book has been published in many countries now, translated into countless different languages from Hungarian to Hebrew. Everywhere children are still reading about the integrity that a small Scandinavian population showed almost seventy years ago. Books do change lives, I know; and many readers have told me that Number the Stars changed theirs when they were young, that it made them think about both cruelty and courage. A young woman recently told that It was something that shaped my idea of how people should be treated, recalling her own fourth grade experience with the book.
The Danish friend who originally told me the story of her childhood in Copenhagen in 1943, and who became the prototype for the fictional Annemarie, is an old woman now. So am I. We both love thinking of the children reading the story today, coming to it for the first time and
realizing that once, for a brief time and in a small place, a group of prejudice-free people honored the humanity of others"""

# %%
word = text.lower()
words = word.split()
print (words)
# Out:
# ['i', 'think', 'the', 'history', 'of', 'denmark', 'has', 'much', 'to', 'teach', 'us', 'all.', 'the', 'book', 'has', 'been', 'published', 'in', 'many', 'countries', 'now,', 'translated', 'into', 'countless', 'different', 'languages', 'from', 'hungarian', 'to', 'hebrew.', 'everywhere', 'children', 'are', 'still', 'reading', 'about', 'the', 'integrity', 'that', 'a', 'small', 'scandinavian', 'population', 'showed', 'almost', 'seventy', 'years', 'ago.', 'books', 'do', 'change', 'lives,', 'i', 'know;', 'and', 'many', 'readers', 'have', 'told', 'me', 'that', 'number', 'the', 'stars', 'changed', 'theirs', 'when', 'they', 'were', 'young,', 'that', 'it', 'made', 'them', 'think', 'about', 'both', 'cruelty', 'and', 'courage.', 'a', 'young', 'woman', 'recently', 'told', 'that', 'it', 'was', 'something', 'that', 'shaped', 'my', 'idea', 'of', 'how', 'people', 'should', 'be', 'treated,', 'recalling', 'her', 'own', 'fourth', 'grade', 'experience', 'with', 'the', 'book.', 'the', 'danish', 'friend', 'w
# ...

# %%
import re
cleanwords = re.sub(r'[^\w\s]', '', text)
word = cleanwords.lower()
words = word.split()
words
# Out:
# ['i',
#  'think',
#  'the',
#  'history',
#  'of',
#  'denmark',
#  'has',
#  'much',
#  'to',
#  'teach',
#  'us',
#  'all',
#  'the',
#  'book',
#  'has',
#  'been',
#  'published',
#  'in',
#  'many',
#  'countries',
#  'now',
#  'translated',
#  'into',
#  'countless',
#  'different',
#  'languages',
#  'from',
#  'hungarian',
#  'to',
#  'hebrew',
#  'everywhere',
#  'children',
#  'are',
#  'still',
#  'reading',
#  'about',
#  'the',
#  'integrity',
#  'that',
#  'a',
#  'small',
#  'scandinavian',
#  'population',
#  'showed',
#  'almost',
#  'seventy',
#  'years',
#  'ago',
#  'books',
#  'do',
#  'change',
#  'lives',
#  'i',
#  'know',
#  'and',
#  'many',
#  'readers',
#  'have',
#  'told',
#  'me',
#  'that',
#  'number',
#  'the',
#  'stars',
#  'changed',
#  'theirs',
#  'when',
#  'they',
#  'were',
#  'young',
#  'that',
#  'it',
#  'made',
#  'them',
#  'think',
#  'about',
#  'both',
#  'cruelty',
#  'and',
#  'courage',
#  'a',
#  'young',
#  'woman',
# ...

# %%
sorted_words = sorted(words)
print(sorted_words)
# Out:
# ['1943', 'a', 'a', 'a', 'a', 'a', 'about', 'about', 'ago', 'all', 'almost', 'am', 'an', 'and', 'and', 'and', 'and', 'and', 'annemarie', 'are', 'be', 'became', 'been', 'book', 'book', 'books', 'both', 'both', 'brief', 'change', 'changed', 'childhood', 'children', 'children', 'coming', 'copenhagen', 'countless', 'countries', 'courage', 'cruelty', 'danish', 'denmark', 'different', 'do', 'everywhere', 'experience', 'fictional', 'first', 'for', 'for', 'for', 'fourth', 'friend', 'from', 'grade', 'group', 'has', 'has', 'have', 'hebrew', 'her', 'her', 'history', 'honored', 'how', 'humanity', 'hungarian', 'i', 'i', 'i', 'idea', 'in', 'in', 'in', 'in', 'integrity', 'into', 'is', 'it', 'it', 'it', 'know', 'languages', 'lives', 'love', 'made', 'many', 'many', 'me', 'me', 'much', 'my', 'now', 'now', 'number', 'of', 'of', 'of', 'of', 'of', 'of', 'old', 'once', 'originally', 'others', 'own', 'people', 'people', 'place', 'population', 'prejudicefree', 'prototype', 'published', 'readers', 'reading', 
# ...

# %%
# Step 1: Import the necessary library
from collections import Counter
import re

# Step 2: Provide the text
text = """I think the history of Denmark has much to teach us all.
The book has been published in many countries now, translated into countless different languages from Hungarian to Hebrew. Everywhere children are still reading about the integrity that a small Scandinavian population showed almost seventy years ago. Books do change lives, I know; and many readers have told me that Number the Stars changed theirs when they were young, that it made them think about both cruelty and courage. A young woman recently told that It was something that shaped my idea of how people should be treated, recalling her own fourth grade experience with the book.
The Danish friend who originally told me the story of her childhood in Copenhagen in 1943, and who became the prototype for the fictional Annemarie, is an old woman now. So am I. We both love thinking of the children reading the story today, coming to it for the first time and
realizing that once, for a brief time and in a small place, a group of prejudice-free people honored the humanity of others."""

# Step 3: Clean and split the text into words
# Convert to lowercase and use regex to filter out non-word characters
# re.findall(pattern, string)

words = re.findall(r'\b\w+\b', text.lower())

# Step 4: Count the frequency of each word
frequency = Counter(words)

# Step 5: Display the frequency list
for word, count in frequency.items():
    print(f"{word}: {count}")
# Out:
# i: 3
# think: 2
# the: 13
# history: 1
# of: 6
# denmark: 1
# has: 2
# much: 1
# to: 3
# teach: 1
# us: 1
# all: 1
# book: 2
# been: 1
# published: 1
# in: 4
# many: 2
# countries: 1
# now: 2
# translated: 1
# into: 1
# countless: 1
# different: 1
# languages: 1
# from: 1
# hungarian: 1
# hebrew: 1
# everywhere: 1
# children: 2
# are: 1
# still: 1
# reading: 2
# about: 2
# integrity: 1
# that: 6
# a: 5
# small: 2
# scandinavian: 1
# population: 1
# showed: 1
# almost: 1
# seventy: 1
# years: 1
# ago: 1
# books: 1
# do: 1
# change: 1
# lives: 1
# know: 1
# and: 5
# readers: 1
# have: 1
# told: 3
# me: 2
# number: 1
# stars: 1
# changed: 1
# theirs: 1
# when: 1
# they: 1
# were: 1
# young: 2
# it: 3
# made: 1
# them: 1
# both: 2
# cruelty: 1
# courage: 1
# woman: 2
# recently: 1
# was: 1
# something: 1
# shaped: 1
# my: 1
# idea: 1
# how: 1
# people: 2
# should: 1
# be: 1
# treated: 1
# recalling: 1
# her: 2
# own: 1
# fourth: 1
# grade: 1
# experience: 1
# with: 1
# danish: 1
# ...

# %%
# Step 1: Provide the text
text ="""I think the history of Denmark has much to teach us all.
The book has been published in many countries now, translated into countless different languages from Hungarian to Hebrew. Everywhere children are still reading about the integrity that a small Scandinavian population showed almost seventy years ago. Books do change lives, I know; and many readers have told me that Number the Stars changed theirs when they were young, that it made them think about both cruelty and courage. A young woman recently told that It was something that shaped my idea of how people should be treated, recalling her own fourth grade experience with the book.
The Danish friend who originally told me the story of her childhood in Copenhagen in 1943, and who became the prototype for the fictional Annemarie, is an old woman now. So am I. We both love thinking of the children reading the story today, coming to it for the first time and
realizing that once, for a brief time and in a small place, a group of prejudice-free people honored the humanity of others."""

# %%
# Step 2: Import the necessary library
import pandas as pd
from collections import Counter
import re

# Step 3: Clean and split the text into words
# Convert to lowercase and use regex to filter out non-word characters
# re.findall(pattern, string)

words = re.findall(r'\b\w+\b', text.lower())

# Step 4: Count the frequency of each word
frequency = Counter(words)

# Convert the frequency data to a DataFrame
df = pd.DataFrame(frequency.most_common(), columns=['Word', 'Frequency'])

# Display the DataFrame
print(df)

# Save the DataFrame as a CSV file
df.to_csv('word_frequency.csv', index=False)
# Out:
#           Word  Frequency
# 0          the         13
# 1           of          6
# 2         that          6
# 3            a          5
# 4          and          5
# ..         ...        ...
# 117  prejudice          1
# 118       free          1
# 119    honored          1
# 120   humanity          1
# 121     others          1
#
# [122 rows x 2 columns]

# %%
import os
print(os.getcwd())
# Out:
# /content
